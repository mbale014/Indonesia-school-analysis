# %% [markdown]
# ==========================================================
#
# Data analysis
#
# Nama : Muhammad Iqbal
#
# Problem : Meskipun pendidikan dasar hingga menengah telah tersedia di berbagai wilayah Kalimantan, masih ditemukan permasalahan serius dalam hal ketersediaan fasilitas pendidikan (seperti ruang kelas dan rombongan belajar) serta tingginya angka putus sekolah, terutama pada jenjang SD. Pada artikel yg di publikasikan [RRI](https://rri.co.id/daerah/1497776/ribuan-anak-di-banjarmasin-putus-sekolah), terdapat ribuan anak yg putus sekolah di Banjarmasin tanpa alasan yg jelas dan pemerintah sampai sekarang masih mengupayakan untuk yang terbaik.
#
# Tujuan : Analisis Kualitas dan Efisiensi Pendidikan Dasar hingga Menengah di pulau Kalimantan Tahun 2021-2024
#
# ==========================================================

# %% [markdown]
# ## Import library

# %% [markdown]
# import library yg akan digunakan pada projek kali ini

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Load file

# %% [markdown]
# Load semua file yg akan dibutuhkan pada projek kali ini. File yg digunakan didapat dari OpenData dan berisi data demografis tentang pendidikan di provinsi yg ada di Indonesia

# %%
# Get current dir path
current_dir = os.getcwd()

# Load and set file name
file_sd_2021 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-dasar-tiap-provinsi-indonesia-sd-2021.csv")
file_sd_2022 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-dasar-tiap-provinsi-indonesia-sd-2022.csv")
file_sd_2023 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-dasar-tiap-provinsi-indonesia-sd-2023.csv")
file_sd_2024 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-dasar-tiap-propinsi-indonesia-sd-2024.csv")

file_smp_2021 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-pertama-smp-tiap-provinsi-indonesia-smp-2021.csv")
file_smp_2022 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-pertama-smp-tiap-provinsi-indonesia-smp-2022.csv")
file_smp_2023 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-pertama-smp-tiap-provinsi-indonesia-smp-2023.csv")
file_smp_2024 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-pertama-smp-tiap-provinsi-indonesia-smp-2024.csv")

file_sma_2021 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-atas-sma-tiap-provinsi-indonesia-sma-2021.csv")
file_sma_2022 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-atas-sma-tiap-provinsi-indonesia-sma-2022.csv")
file_sma_2023 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-atas-sma-tiap-provinsi-indonesia-sma-2023.csv")
file_sma_2024 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-atas-sma-tiap-provinsi-indonesia-sma-2024.csv")

file_smk_2021 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-kejuruan-smk-tiap-provinsi-indonesia-smk-2021.csv")
file_smk_2022 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-kejuruan-smk-tiap-provinsi-indonesia-smk-2022.csv")
file_smk_2023 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-kejuruan-smk-tiap-provinsi-indonesia-smk-2023.csv")
file_smk_2024 = os.path.join(current_dir, "gambaran-umum-keadaan-sekolah-menengah-kejuruan-smk-tiap-provinsi-indonesia-smk-2024.csv")

# %% [markdown]
# Setelah load file, selanjutnya menambahkan tahun yg sesuai dengan data tersebut lalu menggabungkannya

# %%
# Load data SD dan menetapkan tahun
df_sd_2021 = pd.read_csv(file_sd_2021)
df_sd_2021['tahun'] = 2021

df_sd_2022 = pd.read_csv(file_sd_2022)
df_sd_2022['tahun'] = 2022

df_sd_2023 = pd.read_csv(file_sd_2023)
df_sd_2023['tahun'] = 2023

df_sd_2024 = pd.read_csv(file_sd_2024)
df_sd_2024['tahun'] = 2024

# Gabungkan semua data
df_sd_all = pd.concat([df_sd_2021, df_sd_2022, df_sd_2023, df_sd_2024], ignore_index=True)
df_sd_all['jenjang'] = 'SD'

# Tampilkan ringkasan
df_sd_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Provinsi               296 non-null    object
#  1   Sekolah                296 non-null    int64
#  2   Siswa                  296 non-null    int64
#  3   Mengulang              296 non-null    int64
#  4   Putus Sekolah          296 non-null    int64
#  5   Kepala Sekolah & Guru  296 non-null    int64
#  6   Tenaga Kependidikan    296 non-null    int64
#  7   Rombel                 296 non-null    int64
#  8   Ruang Kelas            296 non-null    int64
#  9   Status                 296 non-null    object
#  10  tahun                  296 non-null    int64
#  11  jenjang                296 non-null    object
# dtypes: int64(9), object(3)
# memory usage: 27.9+ KB

# %%
# Load data SMP dan menetapkan tahun
df_smp_2021 = pd.read_csv(file_smp_2021)
df_smp_2021['tahun'] = 2021

df_smp_2022 = pd.read_csv(file_smp_2022)
df_smp_2022['tahun'] = 2022

df_smp_2023 = pd.read_csv(file_smp_2023)
df_smp_2023['tahun'] = 2023

df_smp_2024 = pd.read_csv(file_smp_2024)
df_smp_2024['tahun'] = 2024

# Gabungkan semua data
df_smp_all = pd.concat([df_smp_2021, df_smp_2022, df_smp_2023, df_smp_2024], ignore_index=True)
df_smp_all['jenjang'] = 'SMP'

# Tampilkan ringkasan
df_smp_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Provinsi               296 non-null    object
#  1   Sekolah                296 non-null    int64
#  2   Siswa                  296 non-null    int64
#  3   Mengulang              296 non-null    int64
#  4   Putus Sekolah          296 non-null    int64
#  5   Kepala Sekolah & Guru  296 non-null    int64
#  6   Tenaga Kependidikan    296 non-null    int64
#  7   Rombel                 296 non-null    int64
#  8   Ruang Kelas            296 non-null    int64
#  9   Status                 296 non-null    object
#  10  tahun                  296 non-null    int64
#  11  jenjang                296 non-null    object
# dtypes: int64(9), object(3)
# memory usage: 27.9+ KB

# %%
# Load data SMA dan menetapkan tahun
df_sma_2021 = pd.read_csv(file_sma_2021)
df_sma_2021['tahun'] = 2021

df_sma_2022 = pd.read_csv(file_sma_2022)
df_sma_2022['tahun'] = 2022

df_sma_2023 = pd.read_csv(file_sma_2023)
df_sma_2023['tahun'] = 2023

df_sma_2024 = pd.read_csv(file_sma_2024)
df_sma_2024['tahun'] = 2024

# Gabungkan semua data
df_sma_all = pd.concat([df_sma_2021, df_sma_2022, df_sma_2023, df_sma_2024], ignore_index=True)
df_sma_all['jenjang'] = 'SMA'

# Tampilkan ringkasan
df_sma_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Provinsi               296 non-null    object
#  1   Sekolah                296 non-null    int64
#  2   Siswa                  296 non-null    int64
#  3   Mengulang              296 non-null    int64
#  4   Putus Sekolah          296 non-null    int64
#  5   Kepala Sekolah & Guru  296 non-null    int64
#  6   Tenaga Kependidikan    296 non-null    int64
#  7   Rombel                 296 non-null    int64
#  8   Ruang Kelas            296 non-null    int64
#  9   Status                 296 non-null    object
#  10  tahun                  296 non-null    int64
#  11  jenjang                296 non-null    object
# dtypes: int64(9), object(3)
# memory usage: 27.9+ KB

# %%
# Load data SMK dan menetapkan tahun
df_smk_2021 = pd.read_csv(file_smk_2021)
df_smk_2021['tahun'] = 2021

df_smk_2022 = pd.read_csv(file_smk_2022)
df_smk_2022['tahun'] = 2022

df_smk_2023 = pd.read_csv(file_smk_2023)
df_smk_2023['tahun'] = 2023

df_smk_2024 = pd.read_csv(file_smk_2024)
df_smk_2024['tahun'] = 2024

# Gabungkan semua data
df_smk_all = pd.concat([df_smk_2021, df_smk_2022, df_smk_2023, df_smk_2024], ignore_index=True)
df_smk_all['jenjang'] = 'SMK'

# Tampilkan ringkasan
df_smk_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Provinsi               292 non-null    object
#  1   Sekolah                292 non-null    int64
#  2   Siswa                  292 non-null    int64
#  3   Mengulang              292 non-null    int64
#  4   Putus Sekolah          292 non-null    int64
#  5   Kepala Sekolah & Guru  292 non-null    int64
#  6   Tenaga Kependidikan    292 non-null    int64
#  7   Rombel                 292 non-null    int64
#  8   Ruang Kelas            292 non-null    int64
#  9   Status                 292 non-null    object
#  10  tahun                  292 non-null    int64
#  11  jenjang                292 non-null    object
# dtypes: int64(9), object(3)
# memory usage: 27.5+ KB

# %%
# Gabung semua data sd-sma/smk
df_all = pd.concat([df_sd_all, df_smp_all, df_sma_all, df_smk_all], ignore_index=True)

df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1180 entries, 0 to 1179
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Provinsi               1180 non-null   object
#  1   Sekolah                1180 non-null   int64
#  2   Siswa                  1180 non-null   int64
#  3   Mengulang              1180 non-null   int64
#  4   Putus Sekolah          1180 non-null   int64
#  5   Kepala Sekolah & Guru  1180 non-null   int64
#  6   Tenaga Kependidikan    1180 non-null   int64
#  7   Rombel                 1180 non-null   int64
#  8   Ruang Kelas            1180 non-null   int64
#  9   Status                 1180 non-null   object
#  10  tahun                  1180 non-null   int64
#  11  jenjang                1180 non-null   object
# dtypes: int64(9), object(3)
# memory usage: 110.8+ KB

# %%
# Cek missing data
df_all.isna().sum()
# Out:
# Provinsi                 0
# Sekolah                  0
# Siswa                    0
# Mengulang                0
# Putus Sekolah            0
# Kepala Sekolah & Guru    0
# Tenaga Kependidikan      0
# Rombel                   0
# Ruang Kelas              0
# Status                   0
# tahun                    0
# jenjang                  0
# dtype: int64

# %%
# Cek data duplikat
df_all.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data final bersih dari data duplikat dan tidak ada missing data. Selanjutnya data yg sudah digabung ini akan dilakukan data cleaning untuk analisa yg lebih siap

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Pada data terdapat nama kolom yg masih perlu diubah dan data beberapa perlu dirapikan maka perlu dilakukan data cleaning

# %%
# Data cleaning
df_all['Provinsi'] = df_all['Provinsi'].str.replace("Prov.", "").str.replace(".", "").str.strip()
df_all = df_all.rename(columns=lambda x: x.lower())
df_all = df_all.rename(columns=lambda x: x.replace(" ", "_"))

df_all['provinsi'].unique(), df_all.columns
# Out:
# (array(['DKI Jakarta', 'Jawa Barat', 'Jawa Tengah', 'DI Yogyakarta',
#         'Jawa Timur', 'Aceh', 'Sumatera Utara', 'Sumatera Barat', 'Riau',
#         'Jambi', 'Sumatera Selatan', 'Lampung', 'Kalimantan Barat',
#         'Kalimantan Tengah', 'Kalimantan Selatan', 'Kalimantan Timur',
#         'Sulawesi Utara', 'Sulawesi Tengah', 'Sulawesi Selatan',
#         'Sulawesi Tenggara', 'Maluku', 'Bali', 'Nusa Tenggara Barat',
#         'Nusa Tenggara Timur', 'Papua', 'Bengkulu', 'Maluku Utara',
#         'Banten', 'Kepulauan Bangka Belitung', 'Gorontalo',
#         'Kepulauan Riau', 'Papua Barat', 'Sulawesi Barat',
#         'Kalimantan Utara', 'Luar Negeri', 'Papua Tengah', 'Papua Selatan',
#         'Papua Pegunungan', 'Papua Barat Daya'], dtype=object),
#  Index(['provinsi', 'sekolah', 'siswa', 'mengulang', 'putus_sekolah',
#         'kepala_sekolah_&_guru', 'tenaga_kependidikan', 'rombel', 'ruang_kelas',
#         'status', 'tahun', 'jenjang'],
#        dtype='object'))

# %%
# Export to csv
df_all.to_csv("df_all.csv", index=False)

# %% [markdown]
# # Analisis

# %% [markdown]
# Karena hanya pada pulau Kalimantan saja dilakukan analisa, maka pulau kalimantan yg akan pada analisis kali ini

# %%
df_borneo = df_all[df_all['provinsi'].str.contains('Kalimantan')].reset_index(drop=True)
df_borneo['provinsi'].unique()
# Out:
# array(['Kalimantan Barat', 'Kalimantan Tengah', 'Kalimantan Selatan',
#        'Kalimantan Timur', 'Kalimantan Utara'], dtype=object)

# %%
df_borneo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   provinsi                160 non-null    object
#  1   sekolah                 160 non-null    int64
#  2   siswa                   160 non-null    int64
#  3   mengulang               160 non-null    int64
#  4   putus_sekolah           160 non-null    int64
#  5   kepala_sekolah_&_guru   160 non-null    int64
#  6   tenaga_kependidikan     160 non-null    int64
#  7   rombel                  160 non-null    int64
#  8   ruang_kelas             160 non-null    int64
#  9   status                  160 non-null    object
#  10  tahun                   160 non-null    int64
#  11  jenjang                 160 non-null    object
#  12  rasio_siswa_guru        160 non-null    float64
#  13  rasio_siswa_rombel      160 non-null    float64
# ...

# %% [markdown]
# ## 1. Jumlah siswa dan guru per jenjang dan tahun

# %% [markdown]
# Siswa dan sekolah menunjukkan beban sistem dan cakupan layanan pendidikan. Pertumbuhan jumlah siswa menunjukkan aksesibilitas pendidikan dan lead indicator bagi ketersediaan sekolah/fasilitas. Pada artikel di publish [Times of India](https://timesofindia.indiatimes.com/city/mumbai/maharashtras-draft-visionary-document-increase-school-enrolment-from-41-to-70-in-the-next-four-years-cut-student-dropout-by-nearly-4/articleshow/122589673.cms?utm_source=chatgpt.com), program di India menargetkan peningkatan enrolmen dan penurunan angka putus sekolah sebagai indikator keberhasilan sistem pendidikan.

# %%
students = df_borneo[['siswa', 'sekolah', 'jenjang', 'tahun']]

# %%
# set plot style: grey grid in the background:
sns.set_theme(style="darkgrid")

# Set the figure size
plt.figure(figsize=(8, 8))
ax1 = sns.barplot(x="tahun", y="siswa", hue="jenjang", data=students, errorbar=None)
for container in ax1.containers:
    ax1.bar_label(container)
plt.show()

plt.figure(figsize=(8, 8))
ax2 = sns.barplot(x="tahun", y="sekolah", hue="jenjang", data=students, errorbar=None)
for container in ax2.containers:
    ax2.bar_label(container)
plt.show()

# %% [markdown]
# Terlihat dari plot siswa tiap jenjang dan tahun, jenjang SD dengan jumlah siswa terbanyak diantara yg lain dan SMA paling sedikit. Pergerakan jumlah siswa semua jenjang dari tahun ke tahun cenderung stabil. Melihat plot jumlah sekolah, dari tahun ke tahun terjadi pertumbuhan sekolah di semua jenjang yg tidak begitu signifikan. Ini dapat mengindikasikan, kebutuhan akan banyaknya siswa sekolah yg masuk setiap tahun selurus dengan penambahanan sekolah di setiap jenjang.

# %% [markdown]
# ## 2. Rasio Siswa terhadap Guru

# %% [markdown]
# [UNESCO](https://uis.unesco.org/node/3297547) mendefinisikan rasio siswa–guru sebagai indikator penting mutu pendidikan karena mengukur rata‑rata perhatian guru kepada siswa. Menilai kualitas pembelajaran: semakin rendah rasio, biasanya semakin baik layanan belajar (lebih personal). Rasio ini indikator penting dalam standar pendidikan UNESCO.

# %%
df_borneo["rasio_siswa_guru"] = df_borneo["siswa"] / df_borneo["kepala_sekolah_&_guru"]
sns.lineplot(data=df_borneo, x='tahun', y='rasio_siswa_guru', hue='jenjang', markers=True, errorbar=None)
# Out:
# <Axes: xlabel='tahun', ylabel='rasio_siswa_guru'>

# %% [markdown]
# Dari hasil visualisasi diketahui:
# - Tren Menurun di Semua Jenjang, secara umum, semua jenjang menunjukkan penurunan rasio siswa/guru, artinya jumlah guru bertambah lebih cepat dibanding pertumbuhan siswa. Ini adalah indikator positif kualitas pendidikan.
# - SD masih tertinggi, SD secara konsisten memiliki rasio siswa/guru tertinggi, meski menurun dari ~16,2 ke ~15,7. Ini dapat mengindikasikan sd memiliki jumlah siswa yg banyak dan beban guru sd yg terlalu berat.
# - SMK fluktuatif, SMK mengalami penurunan tajam pada 2022 dan 2023, lalu sedikit naik kembali di 2024. Hal ini, pengurangan siswa SMK, kemungkinan disebabkan oleh pandemi atau minat menurun.
# - SMP & SMA relatif stabil, SMP dan SMA menunjukkan rasio yang relatif stabil dan ideal (~13.5–13.9). Distribusi guru cukup baik di kedua jenjang ini

# %% [markdown]
# ## 3. Tren Putus Sekolah

# %% [markdown]
# Riset [PMC](https://pmc.ncbi.nlm.nih.gov/articles/PMC3763746/) mendapati bahwa peningkatan kinerja sekolah (akademik) sering diikuti penurunan angka putus sekolah. Dampak buruk yg ditimbulkan dari putus sekolah seperti tingkat pengangguran, kriminalitas tinggi, pendapatan rendah, dan beban sosial/ekonomi meningkat. Analisis ini menjadi indikator keberhasilan sistem pendidikan dalam mempertahankan siswa.

# %%
putus_sekolah_trend = df_borneo.groupby(["tahun", "jenjang"])["putus_sekolah"].sum().reset_index()
sns.lineplot(data=putus_sekolah_trend, x='tahun', y='putus_sekolah', hue='jenjang')
# Out:
# <Axes: xlabel='tahun', ylabel='putus_sekolah'>

# %% [markdown]
# Dari visualisasi diketahui:
# - SD : Tren Meningkat, lalu Menurun Tajam. Peningkatan signifikan dari 2021 (2800an) hingga puncaknya di 2023 (3400an) dan Penurunan drastis di 2024 (2600an).Kenaikan bisa disebabkan oleh dampak ekonomi pasca pandemi, yang memaksa anak-anak membantu orang tua bekerja (Referensi : Bappenas, “Dampak Sosial Ekonomi Pandemi COVID-19” (2022)).
# - SMP: Fluktuatif namun Turun di 2024. Cenderung turun di awal, naik kembali pada 2023, dan turun drastis pada 2024. Masa remaja = masa rawan putus sekolah karena faktor ekonomi, pernikahan dini, kurangnya minat belajar, dan juga faktor pandemi.
# - SMA dan SMK: Stabil dan Rendah. SMA & SMK menunjukkan jumlah yang rendah dan relatif stabil dan penurunan paling terlihat di 2022 dan 2024. Siswa di jenjang ini sudah lebih sadar pentingnya pendidikan serta banyak program vokasi dan beasiswa untuk siswa tidak mampu

# %% [markdown]
# ## 4. Rasio Fasilitas (Siswa per Rombel / Ruang Kelas)

# %% [markdown]
# Studi jangka panjang ([Bloom’s 2‑sigma problem](https://en.wikipedia.org/wiki/Bloom%27s_2_sigma_problem)) menekankan bahwa perhatian individual dalam kelompok belajar kecil mendongkrak hasil akademik secara signifikan. Meskipun fokus utama adalah rasio siswa–guru, kepadatan kelas juga penting untuk menunjang kenyamanan dan efektivitas belajar—terutama di sekolah dasar.

# %%
df_borneo["rasio_siswa_rombel"] = df_borneo["siswa"] / df_borneo["rombel"]
df_borneo["rasio_siswa_ruangkelas"] = df_borneo["siswa"] / df_borneo["ruang_kelas"]

sns.catplot(data=df_borneo, x='jenjang', y="rasio_siswa_ruangkelas", col='provinsi', kind='bar', height=4, aspect=.6)

sns.catplot(data=df_borneo, x='jenjang', y="rasio_siswa_rombel", col='provinsi', kind='bar', height=4, aspect=.6)

# %% [markdown]
# Dari visualisasi diketahui:
# - SMK memiliki rasio tertinggi di hampir semua provinsi (terutama Kalbar, Kalsel, Kaltim). Hal ini mengindikasikan SMK cenderung kekurangan ruang kelas, bisa berdampak pada kenyamanan dan konsentrasi belajar
# - Kalimantan Barat menunjukkan variasi paling besar antar jenjang. Hal ini dapat menunjukkan ketimpangan fasilitas antar jenjang
# - Kalimantan Tengah punya rasio yang cenderung lebih rendah dan merata, bisa dijadikan benchmark untuk efisiensi ruang kelas
# - Pada rasio siswa/rombel, polanya hampir serupa dengan rasio siswa/ruang kelas. Rasio siswa/rombel tinggi menandakan beban belajar tinggi dan potensi penurunan kualitas pengajaran. Selain itu, Kalbar dan Kaltim memiliki rasio tinggi di SMA & SMK dimana daerah ini masih perlu pelatihan.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Dari analisis, kesimpulan pada projek ini adalah:
# 1. Angka putus sekolah masih tinggi, terutama di jenjang SD, dengan tren fluktuatif namun tetap dominan dibanding jenjang lain. Ini menunjukkan perlunya perhatian khusus pada pendidikan dasar.
# 2. Rasio siswa terhadap guru menunjukkan penurunan secara umum, yang mengindikasikan perbaikan dalam distribusi tenaga pengajar. Namun, SD masih memiliki rasio tertinggi, menandakan beban guru yang relatif berat di tingkat dasar.
# 3. Rasio siswa terhadap fasilitas (ruang kelas dan rombel) masih tinggi di beberapa jenjang, terutama SD dan SMP. Ketimpangan ini berpotensi menurunkan kualitas pembelajaran dan mendorong siswa keluar dari sistem pendidikan
# 4. Tidak semua provinsi menunjukkan perbaikan yang merata, baik dalam rasio fasilitas maupun penurunan angka putus sekolah. Ini menandakan perlunya kebijakan yang lebih spesifik berdasarkan kondisi daerah
#
# Saran:
# 1. Prioritaskan pembangunan dan perawatan fasilitas pendidikan dasar (SD)
# Karena rasio siswa terhadap ruang kelas dan rombel masih tinggi di jenjang SD, pemerintah daerah perlu:
#     - Membangun ruang kelas baru di daerah padat siswa.
#     - Merevitalisasi sekolah-sekolah rusak agar bisa digunakan optimal
# 2. Perluas rekrutmen dan distribusi guru secara merata
#     - Fokus pada SD yang memiliki rasio siswa-guru tertinggi.
#     - Gunakan data rasio untuk menyusun peta kebutuhan guru per provinsi dan jenjang.
#     - Perkuat program insentif bagi guru yang ditempatkan di daerah 3T (Tertinggal, Terdepan, Terluar)

# %% [markdown]
# Referensi:
# - Peraturan Menteri Pendidikan dan Kebudayaan No. 17 Tahun 2017 tentang Zonasi Pendidikan
# - Rencana Strategis Kementerian Pendidikan, Kebudayaan, Riset, dan Teknologi 2020–2024
# - Data Pokok Pendidikan (Dapodik) dan laporan BPS
